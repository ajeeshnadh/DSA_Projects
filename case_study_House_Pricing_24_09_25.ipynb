# %% [markdown]
# <a href="https://colab.research.google.com/github/ajeeshnadh/DSA_Projects/blob/main/case_study_House_Pricing_24_09_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/House_Pricing.csv')

# %%
  House_Pricing.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2987623597.py in <cell line: 0>()
# ----> 1 House_Pricing.csv
#
# NameError: name 'House_Pricing' is not defined

# %%
display(data)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
new_tita = pd.get_dummies(data,
                               columns = ['your_column_name'], # Replace 'your_column_name' with the actual column name
                               prefix = 'town',
                               drop_first=True,
                               dtype='int64')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-983790506.py in <cell line: 0>()
# ----> 1 new_tita = pd.get_dummies(data,
#       2                                columns = ['your_column_name'], # Replace 'your_column_name' with the actual column name
#       3                                prefix = 'town',
#       4                                drop_first=True,
#       5                                dtype='int64')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# ...

# %%
display(data.columns)
# Out:
# Index(['ID', 'Date House was Sold', 'Sale Price', 'No of Bedrooms',
#        'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
#        'No of Floors', 'Waterfront View', 'No of Times Visited',
#        'Condition of the House', 'Overall Grade',
#        'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)',
#        'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude',
#        'Longitude', 'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
std_scaler = StandardScaler()
min_scaler = MinMaxScaler()
data['Overall Grade_scaled']=std_scaler.fit_transform(data[['Overall Grade']])
display(data.head())
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  \
# 0              No                 NaN  ...
# 1              No                 NaN  ...
# ...

# %%
import numpy as np
num_cols = data.select_dtypes(include=np.float64)
num_cols.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Sale Price'}>,
#         <Axes: title={'center': 'No of Bathrooms'}>,
#         <Axes: title={'center': 'Flat Area (in Sqft)'}>],
#        [<Axes: title={'center': 'Lot Area (in Sqft)'}>,
#         <Axes: title={'center': 'No of Floors'}>,
#         <Axes: title={'center': 'Area of the House from Basement (in Sqft)'}>],
#        [<Axes: title={'center': 'Zipcode'}>,
#         <Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>],
#        [<Axes: title={'center': 'Living Area after Renovation (in Sqft)'}>,
#         <Axes: title={'center': 'Overall Grade_scaled'}>, <Axes: >]],
#       dtype=object)

# %%
data.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
import matplotlib.pyplot as plt
for i in num_cols:
  plt.figure(figsize=(10,5))
  plt.boxplot(num_cols[i].dropna())
  plt.show()

# %%
q1 = np.quantile(data['Sale Price'].dropna(),0.25)
q3 = np.quantile(data['Sale Price'].dropna(),0.75)
iqr = q3-q1

upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

print(upper_bound)
print(lower_bound)
print(iqr)
# Out:
# 1129575.0
# -162625.0
# 323050.0

# %%
spirit_outliers = data[(data['Sale Price'] > upper_bound) | (data['Sale Price'] < lower_bound)]
display(spirit_outliers)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 5      7237550310         14 May 2017   1230000.0               4
# 21     2524049179      14 August 2017   2000000.0               3
# 49      822039084       15 March 2016   1350000.0               3
# 69     1802000060        14 June 2017   1330000.0               5
# 125    4389200955       15 March 2016   1450000.0               4
# ...           ...                 ...         ...             ...
# 21568   524059330     15 January 2016   1700000.0               4
# 21576  9253900271     15 January 2016   3570000.0               5
# 21590  7430200100         14 May 2017   1220000.0               4
# 21597   191100405       15 April 2016   1580000.0               4
# 21600   249000205     14 October 2017   1540000.0               5
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 5                 4.50               5420.0            101930.0           1.0
# ...

# %%
Flat_areas=[]
for i in data['Lot Area (in Sqft)']:
  if i > upper_bound or i < lower_bound:
     Flat_areas.append(i)
display(Flat_areas)
# Out:
# [1651359.0, 1164794.0]

# %%
data['Lot Area (in Sqft)'] = data['Lot Area (in Sqft)'].clip(lower=lower_bound,upper=upper_bound)
plt.boxplot(data['Lot Area (in Sqft)'].dropna())
plt.title('Lot Area (in Sqft)')
plt.show()

# %%
q1_price = np.quantile(data['wine_servings'].dropna(), 0.25)
q3_price = np.quantile(data['wine_servings'].dropna(), 0.75)
iqr_price = q3_price - q1_price
upper_bound_house = q3_price + (1.5 * iqr_flat)
lower_bound_house = q1_price - (1.5 * iqr_flat)

house_outliers = []
for i in data['area']:
  if i > upper_bound_flat or i < lower_bound_flat:
    house_outliers.append(i)
house_outliers
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wine_servings'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-179547861.py in <cell line: 0>()
# ----> 1 q1_price = np.quantile(data['wine_servings'].dropna(), 0.25)
# ...

# %%
data['No of Times Visited'].fillna('Never', inplace=True)
display(data['No of Times Visited'].value_counts())
# Out:
# /tmp/ipython-input-705798063.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['No of Times Visited'].fillna('Never', inplace=True)
# No of Times Visited
# Never     19489
# Twice       963
# Thrice      510
# Once        332
# Four        319
# Name: count, dtype: int64

# %%
data.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'ID'}>,
#         <Axes: title={'center': 'Sale Price'}>,
#         <Axes: title={'center': 'No of Bedrooms'}>,
#         <Axes: title={'center': 'No of Bathrooms'}>],
#        [<Axes: title={'center': 'Flat Area (in Sqft)'}>,
#         <Axes: title={'center': 'Lot Area (in Sqft)'}>,
#         <Axes: title={'center': 'No of Floors'}>,
#         <Axes: title={'center': 'Overall Grade'}>],
#        [<Axes: title={'center': 'Area of the House from Basement (in Sqft)'}>,
#         <Axes: title={'center': 'Basement Area (in Sqft)'}>,
#         <Axes: title={'center': 'Age of House (in Years)'}>,
#         <Axes: title={'center': 'Renovated Year'}>],
#        [<Axes: title={'center': 'Zipcode'}>,
#         <Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'Living Area after Renovation (in Sqft)'}>],
#        [<Axes: title={'center': 'Lot Area after Renovation (in Sqft)'}>,
# ...

# %%
median_bathrooms = data['No of Bathrooms'].median()
data['No of Bathrooms'].fillna(median_bathrooms, inplace=True)
display(data.isna().sum())
# Out:
# /tmp/ipython-input-2973549103.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['No of Bathrooms'].fillna(median_bathrooms, inplace=True)
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# ...
